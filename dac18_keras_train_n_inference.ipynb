# %%
#Reference: 
#   Cunxi Yu, Houping Xiao and Giovanni De Micheli. 
#   "Developing Synthesis Flows without Human Knowledge." ACM/IEEE Design Automation Conference (DAC'18)
#   Contact: Cunxi Yu.  Email: cunxi.yu@epfl.ch
#
#
#Demo: Input design/datasets: 64-bit GF-Mont with delay labels.
#        Number of classes: 7 (0-6)
#Demo 
#    Training Results:
#        1) Angel flows classifcation (class-0): 93%
#        2) Devil flows classifcation (class-0): 89%
#        3) overall accuracy of classifer 74.2%         
#
#    Testing Results (20,000 * 3 test points): 
#        1) Angel flows classifcation (class-0): 93%,92%,93%
#        2) Devil flows classifcation (class-0): 90%,90%,90%
#        3) overall accuracy of classifer 73.6%, 73.4%, 73.6%
#
#     Saved model: dac18_GF_delay_model_save_test.h5

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Conv2D,Flatten,MaxPooling2D
from keras.utils import to_categorical
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# Using TensorFlow backend.
# /Users/cunxiyu/miniconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
def read_csv_data(csv_filename, header=None, num_funcs=6, shuffle_data=True):
    """helper function to read data from csv file
    return X and Y
    X.shape = (num_samples, length_seq, num_funcs)
    Y.shape = (num_samples, num_classes)
    """
    # read data
    data = pd.read_csv(csv_filename, header=header)
    data = data.as_matrix()
    if (shuffle_data):
        data = shuffle(data)

    # extract X and Y
    X = data[:, :-1]#.reshape((-1, int((data.shape[1]-1)/num_funcs), num_funcs))
    X = data[:, :-1].reshape(X.shape[0], 1, 24, 6)
    Y = data[:, -1]

    # convert Y to one-hot vectors
    Y = to_categorical(Y, num_classes=Y.max()+1)

    return X, Y

# %%
from keras.callbacks import Callback
from IPython.display import clear_output
class PlotLearning(Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        self.fig = plt.figure()
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))
        self.i += 1

        #self.plot_history()

    def plot_history(self):
        #f, ax1 = plt.subplots()
        f, (ax1, ax2) = plt.subplots(1, 2, sharex=True)
        clear_output(wait=True)
        ax1.set_yscale('log')
        ax1.plot(self.x, self.losses, label="loss")
        ax1.plot(self.x, self.val_losses, label="val_loss")
        ax1.legend()
        ax2.plot(self.x, self.acc, label="accuracy")
        ax2.plot(self.x, self.val_acc, label="validation accuracy")
        ax2.legend()
        plt.show()

plot_learning = PlotLearning()

# %%
##training input data: test.csv
folder_path = 'datasets/64bitGF/delay/'
csv_filename = 'test.csv'
X, Y = read_csv_data(folder_path + csv_filename, header=None, num_funcs=6)
print("X.shape = ", X.shape)
print("Y.shape = ", Y.shape)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)
# Out:
# ('X.shape = ', (20000, 1, 24, 6))
# ('Y.shape = ', (20000, 7))

# %%
input_shape = (1, 24, 6)
model = Sequential()

num_classes=7
model.add(Conv2D(32, kernel_size=(1, 2),
                 activation='elu',
                 input_shape=input_shape))
model.add(Conv2D(64, (1, 2), activation='elu', name = "conv2"))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(64, activation='selu'))
model.add(Dropout(0.4))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, Y_train,
          batch_size=64,
          epochs=100,
          verbose=2,
          validation_data=(X_test, Y_test), callbacks=[plot_learning])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 1, 23, 32)         416
# _________________________________________________________________
# conv2 (Conv2D)               (None, 1, 22, 64)         4160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 22, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 22, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                90176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 95,207
# Trainable params: 95,207
# Non-trainable params: 0
# _________________________________________________________________
# Train on 14000 samples, validate on 6000 samples
# Epoch 1/100
#  - 2s - loss: 1.2511 - acc: 0.5182 - val_loss: 0.9710 - val_acc: 0.6165
# Epoch 2/100
#  - 2s - loss: 1.0143 - acc: 0.5904 - val_loss: 0.9191 - val_acc: 0.6357
# Epoch 3/100
#  - 2s - loss: 0.9730 - acc: 0.6100 - val_loss: 0.8879 - val_acc: 0.6420
# Epoch 4/100
#  - 2s - loss: 0.9365 - acc: 0.6220 - val_loss: 0.8797 - val_acc: 0.6488
# Epoch 5/100
#  - 2s - loss: 0.9176 - acc: 0.6267 - val_loss: 0.8593 - val_acc: 0.6487
# Epoch 6/100
#  - 2s - loss: 0.9034 - acc: 0.6336 - val_loss: 0.8340 - val_acc: 0.6598
# Epoch 7/100
#  - 2s - loss: 0.8873 - acc: 0.6404 - val_loss: 0.8554 - val_acc: 0.6527
# Epoch 8/100
#  - 2s - loss: 0.8739 - acc: 0.6454 - val_loss: 0.8028 - val_acc: 0.6730
# Epoch 9/100
#  - 2s - loss: 0.8598 - acc: 0.6499 - val_loss: 0.7972 - val_acc: 0.6758
# Epoch 10/100
#  - 2s - loss: 0.8446 - acc: 0.6504 - val_loss: 0.7882 - val_acc: 0.6723
# Epoch 11/100
#  - 2s - loss: 0.8330 - acc: 0.6546 - val_loss: 0.7639 - val_acc: 0.6827
# Epoch 12/100
#  - 2s - loss: 0.8180 - acc: 0.6614 - val_loss: 0.7343 - val_acc: 0.6898
# Epoch 13/100
#  - 2s - loss: 0.8010 - acc: 0.6689 - val_loss: 0.7343 - val_acc: 0.6948
# Epoch 14/100
#  - 2s - loss: 0.8008 - acc: 0.6699 - val_loss: 0.7143 - val_acc: 0.6992
# Epoch 15/100
#  - 2s - loss: 0.7879 - acc: 0.6752 - val_loss: 0.7040 - val_acc: 0.6997
# Epoch 16/100
#  - 2s - loss: 0.7818 - acc: 0.6691 - val_loss: 0.6915 - val_acc: 0.7045
# Epoch 17/100
#  - 2s - loss: 0.7667 - acc: 0.6836 - val_loss: 0.6919 - val_acc: 0.7063
# Epoch 18/100
#  - 2s - loss: 0.7622 - acc: 0.6811 - val_loss: 0.6772 - val_acc: 0.7103
# Epoch 19/100
#  - 2s - loss: 0.7506 - acc: 0.6824 - val_loss: 0.6670 - val_acc: 0.7132
# Epoch 20/100
#  - 2s - loss: 0.7408 - acc: 0.6861 - val_loss: 0.6773 - val_acc: 0.7145
# Epoch 21/100
#  - 2s - loss: 0.7331 - acc: 0.6886 - val_loss: 0.6671 - val_acc: 0.7140
# Epoch 22/100
#  - 2s - loss: 0.7255 - acc: 0.6954 - val_loss: 0.6720 - val_acc: 0.7140
# Epoch 23/100
#  - 2s - loss: 0.7126 - acc: 0.6965 - val_loss: 0.6700 - val_acc: 0.7072
# Epoch 24/100
#  - 2s - loss: 0.7115 - acc: 0.6998 - val_loss: 0.6532 - val_acc: 0.7190
# Epoch 25/100
#  - 2s - loss: 0.7046 - acc: 0.7036 - val_loss: 0.6397 - val_acc: 0.7207
# Epoch 26/100
#  - 2s - loss: 0.6991 - acc: 0.7031 - val_loss: 0.6282 - val_acc: 0.7243
# Epoch 27/100
#  - 2s - loss: 0.6918 - acc: 0.7088 - val_loss: 0.6380 - val_acc: 0.7153
# Epoch 28/100
#  - 2s - loss: 0.6847 - acc: 0.7106 - val_loss: 0.6257 - val_acc: 0.7245
# Epoch 29/100
#  - 2s - loss: 0.6937 - acc: 0.7028 - val_loss: 0.6347 - val_acc: 0.7222
# Epoch 30/100
#  - 2s - loss: 0.6796 - acc: 0.7147 - val_loss: 0.6363 - val_acc: 0.7225
# Epoch 31/100
#  - 2s - loss: 0.6810 - acc: 0.7126 - val_loss: 0.6228 - val_acc: 0.7245
# Epoch 32/100
#  - 2s - loss: 0.6768 - acc: 0.7095 - val_loss: 0.6219 - val_acc: 0.7230
# Epoch 33/100
#  - 2s - loss: 0.6791 - acc: 0.7076 - val_loss: 0.6175 - val_acc: 0.7308
# Epoch 34/100
#  - 2s - loss: 0.6639 - acc: 0.7124 - val_loss: 0.6147 - val_acc: 0.7272
# Epoch 35/100
#  - 2s - loss: 0.6630 - acc: 0.7170 - val_loss: 0.6120 - val_acc: 0.7330
# Epoch 36/100
#  - 2s - loss: 0.6630 - acc: 0.7156 - val_loss: 0.6306 - val_acc: 0.7262
# Epoch 37/100
#  - 2s - loss: 0.6520 - acc: 0.7228 - val_loss: 0.6232 - val_acc: 0.7260
# Epoch 38/100
#  - 2s - loss: 0.6439 - acc: 0.7245 - val_loss: 0.6048 - val_acc: 0.7358
# Epoch 39/100
#  - 2s - loss: 0.6478 - acc: 0.7294 - val_loss: 0.6154 - val_acc: 0.7270
# Epoch 40/100
#  - 2s - loss: 0.6426 - acc: 0.7301 - val_loss: 0.6021 - val_acc: 0.7385
# Epoch 41/100
#  - 2s - loss: 0.6386 - acc: 0.7298 - val_loss: 0.6066 - val_acc: 0.7330
# Epoch 42/100
#  - 2s - loss: 0.6447 - acc: 0.7306 - val_loss: 0.5925 - val_acc: 0.7423
# Epoch 43/100
#  - 2s - loss: 0.6336 - acc: 0.7297 - val_loss: 0.5940 - val_acc: 0.7363
# Epoch 44/100
#  - 2s - loss: 0.6345 - acc: 0.7300 - val_loss: 0.6089 - val_acc: 0.7395
# Epoch 45/100
#  - 2s - loss: 0.6287 - acc: 0.7296 - val_loss: 0.5969 - val_acc: 0.7395
# Epoch 46/100
#  - 2s - loss: 0.6278 - acc: 0.7320 - val_loss: 0.6077 - val_acc: 0.7312
# Epoch 47/100
#  - 2s - loss: 0.6271 - acc: 0.7337 - val_loss: 0.5923 - val_acc: 0.7408
# Epoch 48/100
#  - 2s - loss: 0.6191 - acc: 0.7388 - val_loss: 0.6125 - val_acc: 0.7292
# Epoch 49/100
#  - 2s - loss: 0.6185 - acc: 0.7376 - val_loss: 0.5961 - val_acc: 0.7358
# Epoch 50/100
#  - 2s - loss: 0.6172 - acc: 0.7386 - val_loss: 0.5972 - val_acc: 0.7357
# Epoch 51/100
#  - 2s - loss: 0.6137 - acc: 0.7391 - val_loss: 0.6049 - val_acc: 0.7320
# Epoch 52/100
#  - 2s - loss: 0.6152 - acc: 0.7388 - val_loss: 0.5894 - val_acc: 0.7373
# Epoch 53/100
#  - 2s - loss: 0.6098 - acc: 0.7446 - val_loss: 0.6098 - val_acc: 0.7350
# Epoch 54/100
#  - 2s - loss: 0.6097 - acc: 0.7412 - val_loss: 0.5992 - val_acc: 0.7347
# Epoch 55/100
#  - 2s - loss: 0.5995 - acc: 0.7452 - val_loss: 0.5890 - val_acc: 0.7385
# Epoch 56/100
#  - 2s - loss: 0.6056 - acc: 0.7424 - val_loss: 0.5817 - val_acc: 0.7380
# Epoch 57/100
#  - 2s - loss: 0.5957 - acc: 0.7481 - val_loss: 0.5846 - val_acc: 0.7403
# Epoch 58/100
#  - 2s - loss: 0.5979 - acc: 0.7486 - val_loss: 0.5857 - val_acc: 0.7392
# Epoch 59/100
#  - 2s - loss: 0.5932 - acc: 0.7490 - val_loss: 0.5835 - val_acc: 0.7420
# Epoch 60/100
#  - 2s - loss: 0.5892 - acc: 0.7530 - val_loss: 0.5930 - val_acc: 0.7377
# Epoch 61/100
#  - 2s - loss: 0.5954 - acc: 0.7501 - val_loss: 0.5829 - val_acc: 0.7405
# Epoch 62/100
#  - 2s - loss: 0.5800 - acc: 0.7524 - val_loss: 0.6047 - val_acc: 0.7353
# Epoch 63/100
#  - 2s - loss: 0.5855 - acc: 0.7559 - val_loss: 0.5875 - val_acc: 0.7408
# Epoch 64/100
#  - 2s - loss: 0.5820 - acc: 0.7539 - val_loss: 0.5886 - val_acc: 0.7422
# Epoch 65/100
#  - 2s - loss: 0.5747 - acc: 0.7581 - val_loss: 0.6000 - val_acc: 0.7397
# Epoch 66/100
#  - 2s - loss: 0.5795 - acc: 0.7594 - val_loss: 0.5918 - val_acc: 0.7362
# Epoch 67/100
#  - 2s - loss: 0.5718 - acc: 0.7596 - val_loss: 0.5934 - val_acc: 0.7412
# Epoch 68/100
#  - 2s - loss: 0.5774 - acc: 0.7573 - val_loss: 0.5834 - val_acc: 0.7452
# Epoch 69/100
#  - 2s - loss: 0.5703 - acc: 0.7600 - val_loss: 0.5908 - val_acc: 0.7440
# Epoch 70/100
#  - 2s - loss: 0.5726 - acc: 0.7560 - val_loss: 0.5976 - val_acc: 0.7437
# Epoch 71/100
#  - 2s - loss: 0.5626 - acc: 0.7611 - val_loss: 0.5923 - val_acc: 0.7363
# Epoch 72/100
#  - 2s - loss: 0.5639 - acc: 0.7618 - val_loss: 0.5893 - val_acc: 0.7428
# Epoch 73/100
#  - 2s - loss: 0.5714 - acc: 0.7598 - val_loss: 0.5992 - val_acc: 0.7430
# Epoch 74/100
#  - 2s - loss: 0.5634 - acc: 0.7624 - val_loss: 0.5844 - val_acc: 0.7468
# Epoch 75/100
#  - 2s - loss: 0.5536 - acc: 0.7639 - val_loss: 0.5911 - val_acc: 0.7407
# Epoch 76/100
#  - 2s - loss: 0.5579 - acc: 0.7645 - val_loss: 0.5873 - val_acc: 0.7453
# Epoch 77/100
#  - 2s - loss: 0.5580 - acc: 0.7676 - val_loss: 0.5997 - val_acc: 0.7412
# Epoch 78/100
#  - 2s - loss: 0.5566 - acc: 0.7664 - val_loss: 0.5897 - val_acc: 0.7472
# Epoch 79/100
#  - 2s - loss: 0.5540 - acc: 0.7706 - val_loss: 0.5811 - val_acc: 0.7470
# Epoch 80/100
#  - 2s - loss: 0.5502 - acc: 0.7696 - val_loss: 0.5892 - val_acc: 0.7457
# Epoch 81/100
#  - 2s - loss: 0.5492 - acc: 0.7660 - val_loss: 0.5875 - val_acc: 0.7418
# Epoch 82/100
#  - 2s - loss: 0.5486 - acc: 0.7668 - val_loss: 0.5845 - val_acc: 0.7463
# Epoch 83/100
#  - 2s - loss: 0.5491 - acc: 0.7676 - val_loss: 0.6038 - val_acc: 0.7423
# Epoch 84/100
#  - 2s - loss: 0.5412 - acc: 0.7723 - val_loss: 0.5929 - val_acc: 0.7468
# Epoch 85/100
#  - 2s - loss: 0.5436 - acc: 0.7674 - val_loss: 0.5886 - val_acc: 0.7392
# Epoch 86/100
#  - 2s - loss: 0.5405 - acc: 0.7726 - val_loss: 0.5958 - val_acc: 0.7438
# Epoch 87/100
#  - 2s - loss: 0.5450 - acc: 0.7704 - val_loss: 0.5964 - val_acc: 0.7393
# Epoch 88/100
#  - 2s - loss: 0.5318 - acc: 0.7756 - val_loss: 0.5921 - val_acc: 0.7455
# Epoch 89/100
#  - 2s - loss: 0.5340 - acc: 0.7744 - val_loss: 0.5887 - val_acc: 0.7440
# Epoch 90/100
#  - 2s - loss: 0.5341 - acc: 0.7751 - val_loss: 0.6081 - val_acc: 0.7390
# Epoch 91/100
#  - 2s - loss: 0.5281 - acc: 0.7817 - val_loss: 0.6046 - val_acc: 0.7385
# Epoch 92/100
#  - 2s - loss: 0.5346 - acc: 0.7769 - val_loss: 0.5938 - val_acc: 0.7405
# Epoch 93/100
#  - 2s - loss: 0.5331 - acc: 0.7783 - val_loss: 0.5959 - val_acc: 0.7437
# Epoch 94/100
#  - 2s - loss: 0.5217 - acc: 0.7787 - val_loss: 0.6102 - val_acc: 0.7338
# Epoch 95/100
#  - 2s - loss: 0.5264 - acc: 0.7749 - val_loss: 0.6013 - val_acc: 0.7388
# Epoch 96/100
#  - 2s - loss: 0.5322 - acc: 0.7779 - val_loss: 0.5880 - val_acc: 0.7445
# Epoch 97/100
#  - 2s - loss: 0.5257 - acc: 0.7799 - val_loss: 0.5953 - val_acc: 0.7397
# Epoch 98/100
#  - 2s - loss: 0.5255 - acc: 0.7794 - val_loss: 0.5851 - val_acc: 0.7448
# Epoch 99/100
#  - 2s - loss: 0.5218 - acc: 0.7788 - val_loss: 0.5962 - val_acc: 0.7455
# Epoch 100/100
#  - 2s - loss: 0.5223 - acc: 0.7800 - val_loss: 0.5967 - val_acc: 0.7418

# %%
import h5py
model.save('dac18_GF_delay_model_save_test.h5')

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          print_raw_cm=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        if (print_raw_cm):
            print("Normalized confusion matrix")
    else:
        if (print_raw_cm):
            print('Confusion matrix, without normalization')

    if (print_raw_cm):
        print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Greys)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    #plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
def evaluate(model, X_test, Y_test, classes,NAME):
    """evaluate dataset and plot confusion matrix"""
    # predict from X_test
    Y_pred = model.predict(X_test)
    Y_pred_label = np.argmax(Y_pred, axis=-1)
    Y_test_label = np.argmax(Y_test, axis=-1)


    print("Prediction accuracy = %f" %(float(sum(Y_pred_label == Y_test_label))/Y_test_label.shape[0]))
    cnf_matrix = confusion_matrix(Y_test_label, Y_pred_label)


    np.set_printoptions(precision=2)
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=classes, normalize=True,
                          title='Normalized confusion matrix\n Angel-class:class-0\n Devil-class:class-6')
    
    plt.show()

# %%
##evaluate training results
evaluate(model, X_test, Y_test, classes=range(0,Y.shape[1]),NAME = "origin_delay_")
# Out:
# Prediction accuracy = 0.741833

# %%
plot_learning.plot_history()

# %%
## testing (inference)
# 1st testing input datasets: 20000 untested flows, test2.csv

folder_path = 'datasets/64bitGF/delay/'
csv_filename = 'test2.csv'
X, Y = read_csv_data(folder_path + csv_filename, header=None, num_funcs=6)
print(X.shape, Y.shape)
evaluate(model, X, Y, classes=range(0,Y.shape[1]),NAME = "origin_delay_")
# Out:
# ((20000, 1, 24, 6), (20000, 7))
# Prediction accuracy = 0.736200

# %%
## testing (inference)
# 2nd testing input datasets: 20000 untested flows, test3.csv

folder_path = 'datasets/64bitGF/delay/'
csv_filename = 'test3.csv'
X, Y = read_csv_data(folder_path + csv_filename, header=None, num_funcs=6)
#print(X.shape, Y.shape)
evaluate(model, X, Y, classes=range(0,Y.shape[1]),NAME = "origin_delay_")
# Out:
# Prediction accuracy = 0.733800

# %%
## testing (inference)
# 3rd testing input datasets: 20000 untested flows, test4.csv

folder_path = 'datasets/64bitGF/delay/'
csv_filename = 'test4.csv'
X, Y = read_csv_data(folder_path + csv_filename, header=None, num_funcs=6)
#print(X.shape, Y.shape)
evaluate(model, X, Y, classes=range(0,Y.shape[1]),NAME = "origin_delay_")
# Out:
# Prediction accuracy = 0.736150
